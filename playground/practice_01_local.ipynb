# %%
import duckdb

# %%
con = duckdb.connect()

# %%
path = "sample_data.parquet"

query = f"SELECT * FROM '{path}' LIMIT 5"
print(con.sql(query))
# Out:
# ┌───────┬─────────────────────┬──────────┬────────┬─────────┐
# │  id   │        date         │ category │ value  │ status  │
# │ int64 │    timestamp_ns     │ varchar  │ double │ boolean │
# ├───────┼─────────────────────┼──────────┼────────┼─────────┤
# │     1 │ 2026-01-01 00:00:00 │ C        │ 279.99 │ false   │
# │     2 │ 2026-01-02 00:00:00 │ B        │  170.9 │ true    │
# │     3 │ 2026-01-03 00:00:00 │ A        │ 263.11 │ true    │
# │     4 │ 2026-01-04 00:00:00 │ C        │ 245.21 │ true    │
# │     5 │ 2026-01-05 00:00:00 │ B        │  47.24 │ false   │
# └───────┴─────────────────────┴──────────┴────────┴─────────┘

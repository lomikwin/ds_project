# %%
# 1. SQL 확장 기능 로드
# %load_ext sql
# 2. DuckDB 연결 생성 (메모리 모드)
# 여기서 설정한 연결이 %sql 명령을 내릴 때마다 사용됩니다.
# %sql duckdb:///:memory:
# 3. 데이터 표시 설정 (선택사항)
# 결과가 너무 길면 자동으로 잘라주거나, Pandas DataFrame으로 바로 리턴하도록 설정합니다.
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
print("✅ Zeppelin-style %sql is ready!")
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# ✅ Zeppelin-style %sql is ready!

# %%
# %%sql
#
# select * from 'sample_data.parquet'
# limit 10
# Out:
#    id       date category   value  status
# 0   1 2026-01-01        C  279.99   False
# 1   2 2026-01-02        B  170.90    True
# 2   3 2026-01-03        A  263.11    True
# 3   4 2026-01-04        C  245.21    True
# 4   5 2026-01-05        B   47.24   False
# 5   6 2026-01-06        B   51.95    True
# 6   7 2026-01-07        B   41.76   False
# 7   8 2026-01-08        B  322.37   False
# 8   9 2026-01-09        A  470.85   False
# 9  10 2026-01-10        B   50.07    True
